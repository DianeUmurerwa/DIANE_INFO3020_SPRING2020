# %% [markdown]
# <a href="https://colab.research.google.com/github/DianeUmurerwa/DIANE_INFO3020_SPRING2020/blob/master/pythonExam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pylab import *
figure(1,figsize=(6,6))
ax=axes([0.1,0.1,0.8,0.8])
labels='Spring','Summer','Autumn','Winter'
x=[20,30,45,5]
explode=(0.1,0.1,0.1,0.1)
pie(x,explode=explode,labels=labels,autopct='%1.1f%%',startangle=67)
title('Rainy days by season')
show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,2,3,2,2,1]
plt.plot(x,marker='*')
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3]
y=[5,4,3]
plt.figure()
plt.plot(x,y)
grouplabels=['x','y','z']
plt.xticks(x,grouplabels)
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
x = ('Bill', 'Fred', 'Mary', 'Sue')
money = [1.5, 2.5, 5.5, 2.0]
plt.ylim(0,10)
plt.bar(x, money)
plt.show()
